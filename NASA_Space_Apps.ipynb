# %% [markdown]
# <a href="https://colab.research.google.com/github/Miko6836/Nasa-Space-Apps-wwwpeo-and-friends/blob/main/NASA_Space_Apps.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

# %%
path = '/content/drive/MyDrive/espace_vert.csv'
park_data = pd.read_csv(path)
park_data
path_2 = '/content/drive/MyDrive/auscultation-chaussees-2022-local.csv'
road_data = pd.read_csv(path_2)
road_data
path_3 = '/content/drive/MyDrive/condition-ruelles-2019.csv'
roadcon_data = pd.read_csv(path_3)
roadcon_data
path_4 = '/content/drive/MyDrive/pluviometrie-quantite.csv'
rainfall_data = pd.read_csv(path_4)
rainfall_data
path_5 = '/content/drive/MyDrive/Zones_inondables.csv'
floodzones_data = pd.read_csv(path_5)
floodzones_data
# Out:
#      ID  MUNICIPALITE                   TYPE  OBJECTID   SHAPE__Area  \
# 0   144         43027        Sans récurrence         1  5.020887e+06
# 1   149         43027        Sans récurrence         2  8.298690e+05
# 2   160         43027        Sans récurrence         3  2.611243e+05
# 3   316         43027    Récurrence 0-20 ans         4  3.641836e+02
# 4   317         43027    Récurrence 0-20 ans         5  3.903841e+05
# ..  ...           ...                    ...       ...           ...
# 89  402         43027  Récurrence 20-100 ans        90  2.221057e+04
# 90  403         43027  Récurrence 20-100 ans        91  4.158078e+04
# 91  404         43027  Récurrence 20-100 ans        92  1.732413e+04
# 92  405         43027  Récurrence 20-100 ans        93  2.550589e+04
# 93  406         43027  Récurrence 20-100 ans        94  3.906250e-03
#
#     SHAPE__Length
# 0    51479.635842
# 1    13869.546072
# 2     2856.561005
# 3       85.783078
# 4    10287.390975
# ..            ...
# ...

# %%
park_data[['Type']].head()
# Out:
#    Type
# 0   NaN
# 1   Av.
# 2  Parc
# 3   NaN
# 4   NaN
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# _df_0.groupby('Type').size().plot(kind='barh', color=sns.palettes.mpl_palette('Dark2'))
# plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
print(len(park_data))
# Out:
# 2234

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn.objects as so
sns.scatterplot(x = 'PROPRIETE', y = 'TYPO1', data = park_data, hue="COMPETENCE")
# Out:
# <Axes: xlabel='PROPRIETE', ylabel='TYPO1'>

# %%
park_data.groupby(['COMPETENCE']).count()
# Out:
#                         OBJECTID  Type  Lien   Nom  NUM_INDEX  SUPERFICIE  \
# COMPETENCE
# Agglomération                 98    53    46    98         98          98
# Arrondissement              1701  1147   319  1613       1545        1701
# Gouvernement du Canada         7     1     0     7          7           7
# Gouvernement du Québec        65    24     0    65         29          65
# Local                          3     0     0     3          3           3
# Municipale                    33    29    24    33         33          33
# Privé                         87    47    25    87         49          87
#
#                         PROPRIETE  GESTION  TYPO1  TYPO2
# COMPETENCE
# Agglomération                  98       98     98     53
# Arrondissement               1701     1699   1701   1663
# Gouvernement du Canada          7        7      7      7
# Gouvernement du Québec         65       65     65     65
# Local                           3        3      3      3
# ...

# %%
sns.scatterplot(x = 'PROPRIETE', y = 'GESTION', data = park_data, size = 20, hue="COMPETENCE")
# Out:
# <Axes: xlabel='PROPRIETE', ylabel='GESTION'>

# %%
park_data.groupby(['TYPO1']).count()
# Out:
#                         OBJECTID  Type  Lien   Nom  NUM_INDEX  SUPERFICIE  \
# TYPO1
# Autre espace vert            188    83    40   188        142         188
# BD - Jardin                    1     1     1     1          0           1
# En cours de validation       273     1     0     1          1         273
# Espace voirie                264    90     9   238        218         264
# Grand parc                   130    84    72   130        130         130
# Parc d'arrondissement       1374  1044   293  1350       1275        1374
#
#                         PROPRIETE  GESTION  COMPETENCE  TYPO2
# TYPO1
# Autre espace vert             188      188         188    188
# BD - Jardin                     1        1           1      1
# En cours de validation         38       38          38      0
# Espace voirie                 264      262         264    264
# Grand parc                    130      130         129     85
# ...

# %%
sns.scatterplot(x = 'Arrondissement', y = 'Longueur', data = road_data, size = 20)
# Out:
# <Axes: xlabel='Arrondissement', ylabel='Longueur'>

# %%
sns.scatterplot(x = 'Etat_PCI', y = 'Etat_IRI', data = road_data, size = 1)
# Out:
# <Axes: xlabel='Etat_PCI', ylabel='Etat_IRI'>

# %%
sns.scatterplot(x = 'Rue', y = 'Longueur', data = road_data, size = 20, hue = 'Etat_IRI')
# Out:
# <Axes: xlabel='Rue', ylabel='Longueur'>

# %%
sns.scatterplot(x = 'Arrondissement', y = 'Longueur', data = road_data, hue = 'Etat_IRI')
# Out:
# <Axes: xlabel='Arrondissement', ylabel='Longueur'>

# %%
sns.scatterplot(x = 'Etat_IRI', y = 'Longueur', data = road_data)
# Out:
# <Axes: xlabel='Etat_IRI', ylabel='Longueur'>

# %%
sns.scatterplot(x = 'Etat_PCI', y = 'Etat_IRI', data = road_data)
# Out:
# <Axes: xlabel='Etat_PCI', ylabel='Etat_IRI'>

# %%
road_data.groupby(['Etat_PCI']).count()
# Out:
#               ID_TRC   Rue    De     A  Longueur  Arrondissement  DateReleve  \
# Etat_PCI
# Bon             3219  3219  3161  3143      3219            3219        3219
# Excellent       4183  4183  4123  4078      4183            4183        4183
# Mauvais         3122  3122  3068  3043      3122            3122        3122
# Moyen           2561  2561  2525  2483      2561            2561        2561
# Très mauvais    2736  2736  2685  2670      2736            2736        2736
#
#               Indice_PCI  Indice_IRI  Etat_IRI
# Etat_PCI
# Bon                 3219        2993      2993
# Excellent           4183        3929      3929
# Mauvais             3122        2828      2828
# Moyen               2561        2358      2358
# Très mauvais        2736        2251      2251

# %%
from matplotlib import pyplot as plt
_df_1['ID_TRC'].plot(kind='hist', bins=20, title='ID_TRC')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
sns.scatterplot(x = 'condition_surface', y = 'type_surface', hue ='condition_drainage',data = roadcon_data)
# Out:
# <Axes: xlabel='condition_surface', ylabel='type_surface'>

# %%
sns.scatterplot(x = 'condition_surface', y = 'condition_drainage',hue ='type_surface', data = roadcon_data)
# Out:
# <Axes: xlabel='condition_surface', ylabel='condition_drainage'>

# %%
sns.catplot(x = 'amenagement_vert', y = 'arrondissement', data = roadcon_data)
'''from sklearn import linear_model
X,y = roadcon_data[['amenagement_vert']], roadcon_data[['arrondissement']]

model = linear_model.LinearRegression()
model.fit(X, y)
preds = model.predict(X)

sns.scatterplot(x='amenagement_vert', y='arrondissement', data=roadcon_data)
plt.plot(X, preds, color='r')
plt.legend([ 'Data', 'Linear Regression Fit'])'''
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# "from sklearn import linear_model\nX,y = roadcon_data[['amenagement_vert']], roadcon_data[['arrondissement']]\n\nmodel = linear_model.LinearRegression()\nmodel.fit(X, y)\npreds = model.predict(X)\n\nsns.scatterplot(x='amenagement_vert', y='arrondissement', data=roadcon_data)\nplt.plot(X, preds, color='r')\nplt.legend([ 'Data', 'Linear Regression Fit'])"

# %%
sns.stripplot(x = 'amenagement_vert', y = 'longueur_m', size= 3,data = roadcon_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='amenagement_vert', ylabel='longueur_m'>

# %%
sns.stripplot(x = 'condition_surface', y = 'condition_drainage',hue ='type_surface', data = roadcon_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='condition_surface', ylabel='condition_drainage'>

# %%
rainfall_data.groupby(['NO_SICOS']).count()
# Out:
#           DATE  IMPULSION
# NO_SICOS
# OBXL1011  4076       4076
# OBXL1021  3848       3848
# OBXL1031  4355       4355
# OBXL1041  3707       3707
# OBXL1051  4341       4341
# OBXL1061  4156       4156
# OBXL1081  4427       4427
# OBXL1091  4589       4589
# OBXL1101  4250       4250
# OBXL1111  4419       4419
# OBXL1121  4703       4703
# OBXL1131  4373       4373
# OBXL1141  6404       6404
# OBXL1151  3998       3998
# OBXL1161  3271       3271
# OBXL1211  1349       1349
# OBXL1221  4073       4073
# OBXL1231  4124       4124
# OBXL1241  3310       3310
# OBXL1251  3216       3216
# OBXL1261  4229       4229
# OBXL1271  4723       4723
# OBXL1281  4265       4265
# OBXL1291  4300       4300
# OBXL1301  3764       3764
# OBXL1311  4326       4326
# OBXL1321  4490       4490
# OBXL1331  4379       4379
# OBXL1341  4056       4056
# OBXL1351  3212       3212
# OBXL1361  4004       4004
# OBXL1401  4303       4303
# OBXL1411  3943       3943
# OBXL1431  4003       4003
# ...

# %%
from matplotlib import pyplot as plt
_df_0['DATE'].plot(kind='hist', bins=20, title='DATE')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
data = {
    'NO_SICOS': ['OBXL1011', 'OBXL1021', 'OBXL1031', 'OBXL1041', 'OBXL1051',
                 'OBXL1061', 'OBXL1071', 'OBXL1081', 'OBXL1091', 'OBXL1101',
                 'OBXL1111', 'OBXL1121', 'OBXL1131', 'OBXL1141', 'OBXL1151',
                 'OBXL1161', 'OBXL1171', 'OBXL1181', 'OBXL1191', 'OBXL1201',
                 'OBXL1211', 'OBXL1221', 'OBXL1231', 'OBXL1241', 'OBXL1251',
                 'OBXL1261', 'OBXL1271', 'OBXL1281', 'OBXL1291', 'OBXL1301',
                 'OBXL1311', 'OBXL1321', 'OBXL1331', 'OBXL1341', 'OBXL1351',
                 'OBXL1361', 'OBXL1371', 'OBXL1381', 'OBXL1391', 'OBXL1401',
                 'OBXL1411', 'OBXL1421', 'OBXL1431', 'OBXL1441', 'OBXL1451',
                 'OBXL1461', 'OBXL1471', 'OBXL1481', 'OBXL1491', 'OBXL1501',
                 'OBXL1511', 'OBXL1521', 'OBXL1531', 'OBXL1541', 'OBXL1551',
                 'OBXL1561', 'OBXL1571', 'OBXL1581', 'OBXL1591', 'OBXL1601',
                 'OBXL1611'],
}
replace_dict = {
'OBXL1011': 1,
'OBXL1021': 2,
'OBXL1031': 3,
'OBXL1041': 4,
'OBXL1051': 5,
'OBXL1061': 6,
'OBXL1071': 7,
'OBXL1081': 8,
'OBXL1091': 9,
'OBXL1101': 10,
'OBXL1111': 11,
'OBXL1121': 12,
'OBXL1131': 13,
'OBXL1141': 14,
'OBXL1151': 15,
'OBXL1161': 16,
'OBXL1171': 17,
'OBXL1181': 18,
'OBXL1191': 19,
'OBXL1201': 20,
'OBXL1211': 21,
'OBXL1221': 22,
'OBXL1231': 23,
'OBXL1241': 24,
'OBXL1251': 25,
'OBXL1261': 26,
'OBXL1271': 27,
'OBXL1281': 28,
'OBXL1291': 29,
'OBXL1301': 30,
'OBXL1311': 31,
'OBXL1321': 32,
'OBXL1331': 33,
'OBXL1341': 34,
'OBXL1351': 35,
'OBXL1361': 36,
'OBXL1371': 37,
'OBXL1381': 38,
'OBXL1391': 39,
'OBXL1401': 40,
'OBXL1411': 41,
'OBXL1421': 42,
'OBXL1431': 43,
'OBXL1441': 44,
'OBXL1451': 45,
'OBXL1461': 46,
'OBXL1471': 47,
'OBXL1481': 48,
'OBXL1491': 49,
'OBXL1501': 50,
'OBXL1511': 51,
'OBXL1521': 52,
'OBXL1531': 53,
'OBXL1541': 54,
'OBXL1551': 55,
'OBXL1561': 56,
'OBXL1571': 57,
'OBXL1581': 58,
'OBXL1591': 59,
'OBXL1601': 60,
'OBXL1611': 61
}
rainfall_data['NO_SICOS'] = rainfall_data['NO_SICOS'].replace(replace_dict)
g = (so.Plot(rainfall_data, x="NO_SICOS", y="IMPULSION").add(so.Bar(), so.Count()))
g.label(x="Identifiant du pluviomètre", y="Impulsion équivalente à 1= pluie de 0,25 mm",title="Répartition des impulsion par pluviomètre(2022)")

# %%
sns.scatterplot(x = 'Etat_PCI', y = 'Arrondissement', data = road_data)
# Out:
# <Axes: xlabel='Etat_PCI', ylabel='Arrondissement'>

# %%
sns.stripplot(x = 'Etat_PCI', y = 'Longueur', size= 1,data = road_data)
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# <Axes: xlabel='Etat_PCI', ylabel='Longueur'>

# %%
filtered_data = road_data[road_data['Etat_PCI'].isin(['Très mauvais', 'Mauvais'])]

sns.stripplot(x = 'Longueur', y = 'Arrondissement', size= 2, hue = 'Etat_PCI',data = filtered_data)
plt.title('Les routes des États insatisfaisants nécessitent une auscultation pour chaque district(2022)')
# Out:
# /usr/local/lib/python3.10/dist-packages/seaborn/_base.py:949: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)
# Text(0.5, 1.0, 'Les routes des États insatisfaisants nécessitent une auscultation pour chaque district(2022)')

# %%
filtered_data = roadcon_data[roadcon_data['condition_drainage'].isin(['Très mauvais', 'Mauvais','Passable'])]

sns.stripplot(x = 'condition_drainage', y = 'arrondissement',hue ='cote_globale',palette='ch:s=-.2,r=.6', size= 5,data = filtered_data)
plt.title('Conditions de drainage des routes insatisfaisantes pour tous les districts(2019)')
plt.xlabel("Conditions de drainage")
plt.ylabel("Arrondissement")
# Out:
# Text(0, 0.5, 'Arrondissement')

# %%
sns.scatterplot(x = 'TYPE', y = 'SHAPE__Area',hue='TYPE',size="SHAPE__Area",data = floodzones_data)
plt.title("Type d'inondation par rapport à la taille de la zone touchée")
# Out:
# Text(0.5, 1.0, "Type d'inondation par rapport à la taille de la zone touchée")

# %%
sns.catplot(x = 'TYPE', y = 'SHAPE__Area',hue='TYPE',palette="deep",jitter =True,data = floodzones_data)
plt.title("Type d'inondation par rapport à la taille de la zone touchée")
# Out:
# Text(0.5, 1.0, "Type d'inondation par rapport à la taille de la zone touchée")

# %%
sns.stripplot(x = 'TYPE', y = 'SHAPE__Area',hue='TYPE',palette='viridis',jitter =True,data = floodzones_data)
plt.title("Type d'inondation par rapport à la taille de la zone touchée")
plt.xlabel("Type d'inondation")
plt.ylabel("Taille de la zone touchée")
# Out:
# Text(0, 0.5, 'Taille de la zone touchée')
